# %%
import pandas as pd
import matplotlib
% matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics

# %%
data = pd.read_csv('bank.csv',sep=";")

# %% [markdown]
# # Use the file bank.csv to explore the dataset. Observe the features: Are they
# numbers? Are they strings? Are they binary? Are they continuous?

# %%
data.head(10)
#Columns are mixture of strings, number, and binary.
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %%
data['y'] = data.y.map({'no':0, 'yes':1})

# %% [markdown]
# # Learn about label encoders at the following link and use what you learn to
# transform the features to numerical features.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn import feature_extraction

# %%
cat_columns = ['job', 'marital', 'education','default','balance','housing','loan','contact','month','poutcome']
def dataencoder(data):
    cat_dict = data[cat_columns].to_dict(outtype='records')
    vec = feature_extraction.DictVectorizer()
    cat_vector = vec.fit_transform(cat_dict).toarray()
    df_vector = pd.DataFrame(cat_vector)
    vector_columns = vec.get_feature_names()
    vector_columns
    df_vector.columns = vector_columns
    df_vector.index = data.index
    data = data.drop(cat_columns, axis=1)
    data = data.join(df_vector)
    return data

# %%
data=dataencoder(data)

# %%
data.head(10)
# Out:
#    age  day  duration  campaign  pdays  previous  y  balance  \
# 0   30   19        79         1     -1         0  0     1787
# 1   33   11       220         1    339         4  0     4789
# 2   35   16       185         1    330         1  0     1350
# 3   30    3       199         4     -1         0  0     1476
# 4   59    5       226         1     -1         0  0        0
# 5   35   23       141         2    176         3  0      747
# 6   36   14       341         1    330         2  0      307
# 7   39    6       151         2     -1         0  0      147
# 8   41   14        57         2     -1         0  0      221
# 9   43   17       313         1    147         2  0      -88
#
#    contact=cellular  contact=telephone  contact=unknown  default=no  \
# 0                 1                  0                0           1
# 1                 1                  0                0           1
# 2                 1                  0                0           1
# ...

# %% [markdown]
# # Build a decision tree model to predict whether a prospect will buy the product.

# %%
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeRegressor
feature_cols = data.columns[:]
X = data[feature_cols]
X=X.drop('y', axis=1)
y = data.y
treereg = DecisionTreeRegressor(random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
treereg.fit(X_train, y_train)
preds = treereg.predict(X_test)
np.sqrt(metrics.mean_squared_error(y_test, preds))
# Out:
# 0.38195365447192181

# %% [markdown]
# # Evaluate the accuracy of your decision tree model using cross validation.

# %%
from sklearn.cross_validation import cross_val_score

# %%
treereg = DecisionTreeRegressor(max_depth=5, random_state=1)
scores = cross_val_score(treereg, X, y, cv=5, scoring='mean_squared_error')
np.mean(np.sqrt(-scores))
# Out:
# 0.28845363634627436

# %% [markdown]
# # Repeat the analysis and cross validation with the file bank-additional-full.csv.
# How does the performance of the model change (with the additional training
# examples and additional features)?

# %%
bigdata = pd.read_csv('bank-additional-full.csv',sep=";")

# %%
cat_columns = ['job', 'marital', 'education','default','housing','loan','contact','month','day_of_week','poutcome']
bigdata.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
bigdata=dataencoder(bigdata)
bigdata['y'] = bigdata.y.map({'no':0, 'yes':1})

# %%
feature_cols = bigdata.columns[:]
X1 = bigdata[feature_cols]
X1=X1.drop('y', axis=1)
y1 = bigdata.y
treereg = DecisionTreeRegressor(random_state=1)
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, random_state=1)
treereg.fit(X1_train, y1_train)
preds = treereg.predict(X1_test)
np.sqrt(metrics.mean_squared_error(y1_test, preds))
# Out:
# 0.33214965778040462

# %%
treereg = DecisionTreeRegressor(max_depth=5, random_state=1)
scores = cross_val_score(treereg, X1, y1, cv=5, scoring='mean_squared_error')
np.mean(np.sqrt(-scores))
# Out:
# 0.26574852975210589

# %%
#Performance is improved with more data
